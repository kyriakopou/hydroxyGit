% %% [markdown]
% #Genome Wide Hydroxymethylation Report

% %%
addpath(genpath(pwd));
format compact;
format short;

% %%
inputMatFile = 'T_input.mat';
outputMatFile = 'BI_WG';
errorsFile = '~/Documents/code/MATLAB/Hydroxymethylation/genomeWide/RRHPBS.test.data/errors.txt';

analyzeInput(inputMatFile);
% Out:
%         chr         GroupCount    nanmean_bs0    nanmean_bs3    nanmean_bs6
%     ____________    __________    ___________    ___________    ___________
%     '1'             1.5882e+05    35.577         37.524         61.444
%     '10'            1.2004e+05    30.741         32.898         54.839
%     '11'             1.606e+05    30.686         33.039         55.171
%     '12'            1.0362e+05    30.438         32.377         54.043
%     '13'            1.0120e+05    30.177         32.004         53.298
%     '14'                 90678    31.222         33.281         55.545
%     '15'            1.0102e+05    30.456         32.929         54.558
%     '16'                 77341    29.769         32.029         53.219
%     '17'            1.0528e+05    34.122         35.856         59.488
%     '18'                 74811      29.3         31.369         52.317
%     '19'                 68431     29.55         31.833         53.062
% ...

% %%
compareInputOutput(inputMatFile, outputMatFile, errorsFile);

% %%
% Out:
% ans =
%     0.5143   -0.0442    0.7001   -0.0356    0.4049    0.0159    0.9486

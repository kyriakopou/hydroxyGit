% %% [markdown]
% # Clustering of the efficiencies
%
% ## Matlab code

% %%
%add the necesary paths
addpath(genpath(pwd));
cd genomeWide/

% %% [markdown]
% ### kMeans Clustering

% %%
%file name of the .mat table containing the results
%and its compact form 
compFileName = '~/Desktop/DeepResults/WT/matFiles/BI_WG_compact.mat';
fileName = '~/Desktop/DeepResults/WT/matFiles/BI_WG.mat';

%define function's params
clusteringMethod = 'kmeans';
dataToBeClustered = 'eff';
distance = 'cosine';

%perform clustering
T = performClustering(fileName, compFileName, clusteringMethod, dataToBeClustered, distance);
% Out:
% Replicate 1, 15 iterations, total sum of distances = 264.617.
% Best total sum of distances = 264.617
% There are 2967 CpGs in cluster 1
% There are 1245 CpGs in cluster 2
% There are 1359 CpGs in cluster 3
% There are 4429 CpGs in cluster 4
